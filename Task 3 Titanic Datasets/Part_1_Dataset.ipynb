# %% [markdown]
# # Create My Own Dataset (Using Dictionary)

# %% [markdown]
# ### Step 1: Create a dictionary with 5 columns and 15 rows

# %%
# Topic: Student performance data
student_data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eva',
             'Frank', 'Grace', 'Henry', 'Ivy', 'Jack',
             'Kate', 'Leo', 'Mia', 'Noah', 'Olivia'],
    'Age': [20, 21, 19, 22, 20, 23, 21, 20, 22, 19,
            21, 20, 22, 21, 19],
    'Subject': ['Math', 'Science', 'Math', 'English', 'Science',
                'Math', 'English', 'Science', 'Math', 'English',
                'Science', 'Math', 'English', 'Science', 'Math'],
    'Score': [85, 92, 78, 88, 95, 72, 90, 68, 82, 75,
              91, 79, 86, 93, 77],
    'Grade': ['B', 'A', 'C', 'B+', 'A+', 'C-', 'A', 'D+', 'B', 'B-',
              'A', 'C+', 'B+', 'A', 'C']
}

# %% [markdown]
# ### Step 2: Create custom index (Student IDs)

# %%
custom_index = ['STU001', 'STU002', 'STU003', 'STU004', 'STU005',
                'STU006', 'STU007', 'STU008', 'STU009', 'STU010',
                'STU011', 'STU012', 'STU013', 'STU014', 'STU015']

# %% [markdown]
# ### Step 3: Create DataFrame with custom index

# %%
df_students = pd.DataFrame(student_data, index=custom_index)

# %%
# display the result
df_students
# Out:
#            Name  Age  Subject  Score Grade
# STU001    Alice   20     Math     85     B
# STU002      Bob   21  Science     92     A
# STU003  Charlie   19     Math     78     C
# STU004    Diana   22  English     88    B+
# STU005      Eva   20  Science     95    A+
# STU006    Frank   23     Math     72    C-
# STU007    Grace   21  English     90     A
# STU008    Henry   20  Science     68    D+
# STU009      Ivy   22     Math     82     B
# STU010     Jack   19  English     75    B-
# STU011     Kate   21  Science     91     A
# STU012      Leo   20     Math     79    C+
# STU013      Mia   22  English     86    B+
# STU014     Noah   21  Science     93     A
# STU015   Olivia   19     Math     77     C
